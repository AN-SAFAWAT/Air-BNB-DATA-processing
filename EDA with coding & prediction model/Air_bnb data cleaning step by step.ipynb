# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', None)
plt.show()

# %%
df= pd .read_csv('Airbnb_Open_Data.csv')
df.head(10)
# Out:
# /var/folders/kt/w2tnp7fd53b85rxnn34tkb940000gn/T/ipykernel_10446/154860406.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd .read_csv('Airbnb_Open_Data.csv')
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6  1004650                                   BlissArtsSpace!  61300605564
# 7  1005202                                   BlissArtsSpace!  90821839709
# 8  1005754                   Large Furnished Room Near B'way  79384379533
# 9  1006307                Cozy Clean Guest Room - Family Apt  75527839483
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 2                    NaN     Elise           Manhattan              Harlem
# 3            unconfirmed     Garry            Brooklyn        Clinton Hill
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 6                    NaN   Alberta            Brooklyn  Bedford-Stuyvesant
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
# 8               verified    Evelyn           Manhattan      Hell's Kitchen
# 9            unconfirmed      Carl           Manhattan     Upper West Side
#
#         lat      long        country country code instant_bookable  \
# 0  40.64749 -73.97237  United States           US            False
# 1  40.75362 -73.98377  United States           US            False
# 2  40.80902 -73.94190  United States           US             True
# 3  40.68514 -73.95976  United States           US             True
# 4  40.79851 -73.94399  United States           US            False
# 5  40.74767 -73.97500  United States           US             True
# 6  40.68688 -73.95596  United States           US            False
# 7  40.68688 -73.95596  United States           US            False
# 8  40.76489 -73.98493  United States           US             True
# 9  40.80178 -73.96723  United States           US            False
#
#   cancellation_policy        room type  Construction year    price  \
# 0              strict     Private room             2020.0    $966
# 1            moderate  Entire home/apt             2007.0    $142
# 2            flexible     Private room             2005.0    $620
# 3            moderate  Entire home/apt             2005.0    $368
# 4            moderate  Entire home/apt             2009.0    $204
# 5            flexible  Entire home/apt             2013.0    $577
# 6            moderate     Private room             2015.0     $71
# 7            moderate     Private room             2009.0  $1,060
# 8              strict     Private room             2005.0  $1,018
# 9              strict     Private room             2015.0    $291
#
#   service fee  minimum nights  number of reviews last review  \
# 0       $193             10.0                9.0  10/19/2021
# 1        $28             30.0               45.0   5/21/2022
# 2       $124              3.0                0.0         NaN
# 3        $74             30.0              270.0    7/5/2019
# 4        $41             10.0                9.0  11/19/2018
# 5       $115              3.0               74.0   6/22/2019
# 6        $14             45.0               49.0   10/5/2017
# 7       $212             45.0               49.0   10/5/2017
# 8       $204              2.0              430.0   6/24/2019
# 9        $58              2.0              118.0   7/21/2017
#
#    reviews per month  review rate number  calculated host listings count  \
# 0               0.21                 4.0                             6.0
# 1               0.38                 4.0                             2.0
# 2                NaN                 5.0                             1.0
# 3               4.64                 4.0                             1.0
# 4               0.10                 3.0                             1.0
# 5               0.59                 3.0                             1.0
# 6               0.40                 5.0                             1.0
# 7               0.40                 5.0                             1.0
# 8               3.47                 3.0                             1.0
# 9               0.99                 5.0                             1.0
#
#    availability 365                                        house_rules license
# 0             286.0  Clean up and treat the home the way you'd like...     NaN
# 1             228.0  Pet friendly but please confirm with me if the...     NaN
# 2             352.0  I encourage you to use my kitchen, cooking and...     NaN
# 3             322.0                                                NaN     NaN
# 4             289.0  Please no smoking in the house, porch or on th...     NaN
# 5             374.0                  No smoking, please, and no drugs.     NaN
# 6             224.0  Please no shoes in the house so bring slippers...     NaN
# 7             219.0  House Guidelines for our BnB We are delighted ...     NaN
# 8             180.0  - Please clean up after yourself when using th...     NaN
# 9             375.0  NO SMOKING OR PETS ANYWHERE ON THE PROPERTY 1....     NaN

# %%
df = df.replace(" ","",regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
#  12  cancellation_policy             102523 non-null  object
#  13  room type                       102599 non-null  object
#  14  Construction year               102385 non-null  float64
#  15  price                           102352 non-null  object
#  16  service fee                     102326 non-null  object
#  17  minimum nights                  102190 non-null  float64
#  18  number of reviews               102416 non-null  float64
#  19  last review                     86706 non-null   object
#  20  reviews per month               86720 non-null   float64
#  21  review rate number              102273 non-null  float64
#  22  calculated host listings count  102280 non-null  float64
#  23  availability 365                102151 non-null  float64
#  24  house_rules                     50468 non-null   object
#  25  license                         2 non-null       object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 20.4+ MB

# %%
#missing values in some of the column
#need to change the Data types of some of the columns

# %% [markdown]
# Data Cleaning

# %%
#find out duplicate values in the Dataset
df.duplicated().sum()
# Out:
# 541

# %%
#first we need to drop the duplicate rows to make the analysis more precise
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
#drop unwanted columns for analysis

# %%
df.drop(["id","NAME","host id","license","house_rules","country","country code"],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
#
#         lat      long instant_bookable cancellation_policy       room type  \
# 0  40.64749 -73.97237            False              strict     Privateroom
# 1  40.75362 -73.98377            False            moderate  Entirehome/apt
# 2  40.80902 -73.94190             True            flexible     Privateroom
#
#    Construction year price service fee  minimum nights  number of reviews  \
# 0             2020.0  $966        $193            10.0                9.0
# 1             2007.0  $142         $28            30.0               45.0
# 2             2005.0  $620        $124             3.0                0.0
#
#   last review  reviews per month  review rate number  \
# 0  10/19/2021               0.21                 4.0
# 1   5/21/2022               0.38                 4.0
# 2         NaN                NaN                 5.0
#
#    calculated host listings count  availability 365
# 0                             6.0             286.0
# 1                             2.0             228.0
# 2                             1.0             352.0

# %%
#find out missing values in the dataset
df.isnull().sum()
# Out:
# host_identity_verified              289
# host name                           404
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      400
# number of reviews                   183
# last review                       15832
# reviews per month                 15818
# review rate number                  319
# calculated host listings count      319
# availability 365                    448
# dtype: int64

# %%
df['review_year']= pd.to_datetime(df['last review'])
df.drop('last review',axis=1,inplace=True)

# %%
df.review_year.isna().sum()
# Out:
# 15832

# %%
#replace not given Year with value 0 as we do not know the value and it is the best way

# %%
df.review_year.fillna(0,inplace=True)

# %%
#working review per month null values.
df['reviews per month'].isna().sum()
# Out:
# 15818

# %%
df['reviews per month'].fillna(df['reviews per month'].mean(),inplace=True)

# %%
df['reviews per month']
# Out:
# 0         0.210000
# 1         0.380000
# 2         1.375408
# 3         4.640000
# 4         0.100000
#             ...
# 102053    0.440000
# 102054    0.720000
# 102055    3.120000
# 102056    1.375408
# 102057    0.850000
# Name: reviews per month, Length: 102058, dtype: float64

# %%
df['availability 365'].isna().sum()

#Availability values null means it was not available for whole year.
# Out:
# 448

# %%
df['availability 365'].fillna(0,inplace=True)

# %%
df.isna().sum()
# Out:
# host_identity_verified            289
# host name                         404
# neighbourhood group                29
# neighbourhood                      16
# lat                                 8
# long                                8
# instant_bookable                  105
# cancellation_policy                76
# room type                           0
# Construction year                 214
# price                             247
# service fee                       273
# minimum nights                    400
# number of reviews                 183
# reviews per month                   0
# review rate number                319
# calculated host listings count    319
# availability 365                    0
# review_year                         0
# dtype: int64

# %%
sns.distplot(df['number of reviews'])
# Out:
# /Users/leo_mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number of reviews', ylabel='Density'>

# %%
#working with null values in number of reviews column
df[df['number of reviews'].isna()]
# Out:
#        host_identity_verified host name neighbourhood group   neighbourhood  \
# 97                   verified    Sydney           Manhattan   UpperWestSide
# 141                  verified    Martin            Brooklyn      Greenpoint
# 566               unconfirmed     Alisa           Manhattan     EastVillage
# 1066                 verified    Sharma              Queens  JacksonHeights
# 1591                 verified     Ellen           Manhattan   UpperWestSide
# ...                       ...       ...                 ...             ...
# 91027             unconfirmed    Eunice           Manhattan         Chelsea
# 91831             unconfirmed  Vladimir           Manhattan   UpperEastSide
# 99736             unconfirmed    Naveen            Brooklyn    Williamsburg
# 100590            unconfirmed    Andrea           Manhattan   LowerEastSide
# 101292               verified    Eunice           Manhattan         Chelsea
#
#              lat      long instant_bookable cancellation_policy  \
# 97      40.79764 -73.96177             True              strict
# 141     40.73409 -73.95348            False            moderate
# 566     40.72956 -73.97903            False              strict
# 1066    40.74906 -73.89377             True            flexible
# 1591    40.79241 -73.97111            False              strict
# ...          ...       ...              ...                 ...
# 91027   40.74089 -74.00002            False              strict
# 91831   40.76830 -73.95919            False            moderate
# 99736   40.71365 -73.96232             True            flexible
# 100590  40.71833 -73.98556             True              strict
# 101292  40.74089 -74.00002            False              strict
#
#              room type  Construction year price service fee  minimum nights  \
# 97      Entirehome/apt             2017.0  $343         $69             NaN
# 141     Entirehome/apt             2016.0  $488         $98             NaN
# 566     Entirehome/apt             2007.0  $844        $169             1.0
# 1066       Privateroom                NaN  $399         $80             7.0
# 1591    Entirehome/apt             2021.0  $564        $113             3.0
# ...                ...                ...   ...         ...             ...
# 91027   Entirehome/apt             2021.0  $695        $139             2.0
# 91831   Entirehome/apt             2003.0  $151         $30             4.0
# 99736      Privateroom             2022.0  $546        $109             3.0
# 100590     Privateroom             2015.0  $671        $134             4.0
# 101292  Entirehome/apt             2021.0  $695        $139             2.0
#
#         number of reviews  reviews per month  review rate number  \
# 97                    NaN               0.71                 NaN
# 141                   NaN               0.03                 4.0
# 566                   NaN               0.65                 3.0
# 1066                  NaN               0.64                 5.0
# 1591                  NaN               0.43                 5.0
# ...                   ...                ...                 ...
# 91027                 NaN               0.13                 1.0
# 91831                 NaN               1.33                 1.0
# 99736                 NaN               0.38                 1.0
# 100590                NaN               0.63                 4.0
# 101292                NaN               0.13                 1.0
#
#         calculated host listings count  availability 365          review_year
# 97                                 1.0              55.0  2019-07-07 00:00:00
# 141                                1.0             325.0                    0
# 566                                1.0              85.0  2019-07-01 00:00:00
# 1066                               3.0             126.0  2018-09-30 00:00:00
# 1591                               1.0             194.0  2018-09-18 00:00:00
# ...                                ...               ...                  ...
# 91027                              1.0               0.0  2019-01-01 00:00:00
# 91831                              1.0               4.0  2019-06-25 00:00:00
# 99736                              1.0             188.0  2018-10-10 00:00:00
# 100590                             2.0             244.0  2019-06-25 00:00:00
# 101292                             1.0               0.0  2019-01-01 00:00:00
#
# [183 rows x 19 columns]

# %%
df['number of reviews'].mode()
# Out:
# 0    0.0
# Name: number of reviews, dtype: float64

# %%
#as number of review not given for some rows we can assume that number of review is 0 for this rows which is also mode for this column
df['number of reviews'].fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102058 entries, 0 to 102057
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   host_identity_verified          101769 non-null  object
#  1   host name                       101654 non-null  object
#  2   neighbourhood group             102029 non-null  object
#  3   neighbourhood                   102042 non-null  object
#  4   lat                             102050 non-null  float64
#  5   long                            102050 non-null  float64
#  6   instant_bookable                101953 non-null  object
#  7   cancellation_policy             101982 non-null  object
#  8   room type                       102058 non-null  object
#  9   Construction year               101844 non-null  float64
#  10  price                           101811 non-null  object
#  11  service fee                     101785 non-null  object
#  12  minimum nights                  101658 non-null  float64
#  13  number of reviews               102058 non-null  float64
#  14  reviews per month               102058 non-null  float64
#  15  review rate number              101739 non-null  float64
#  16  calculated host listings count  101739 non-null  float64
#  17  availability 365                102058 non-null  float64
#  18  review_year                     102058 non-null  object
# dtypes: float64(9), object(10)
# memory usage: 15.6+ MB

# %% [markdown]
# as we can see service fee and price column has object data type
# i need to change the data type to numaric and remove the string $ from there

# %%
df["service fee"] = df["service fee"].str.replace("$","",regex=True)
df["service fee"]=df["service fee"].astype('float')
df["service fee"].isnull().sum()
# Out:
# 273

# %%
#Checking outlier in service fee
sns.distplot(df["service fee"])
# Out:
# /Users/leo_mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='service fee', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102058 entries, 0 to 102057
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   host_identity_verified          101769 non-null  object
#  1   host name                       101654 non-null  object
#  2   neighbourhood group             102029 non-null  object
#  3   neighbourhood                   102042 non-null  object
#  4   lat                             102050 non-null  float64
#  5   long                            102050 non-null  float64
#  6   instant_bookable                101953 non-null  object
#  7   cancellation_policy             101982 non-null  object
#  8   room type                       102058 non-null  object
#  9   Construction year               101844 non-null  float64
#  10  price                           101811 non-null  object
#  11  service fee                     101785 non-null  float64
#  12  minimum nights                  101658 non-null  float64
#  13  number of reviews               102058 non-null  float64
#  14  reviews per month               102058 non-null  float64
#  15  review rate number              101739 non-null  float64
#  16  calculated host listings count  101739 non-null  float64
#  17  availability 365                102058 non-null  float64
#  18  review_year                     102058 non-null  object
# dtypes: float64(10), object(9)
# memory usage: 15.6+ MB

# %%
#. NO outliers spotted.
#most of the hotel has almost same ammount of service fees so we can fill the null with mean values.
df['service fee'].fillna(df['service fee'].mean(),inplace=True)

# %%
df["price"] = df["price"].str.replace("$","",regex=True)
df["price"] = df["price"].str.replace(",","",regex=True)
df["price"]=df["price"].astype('float')
df["price"].isnull().sum()
# Out:
# 247

# %%
#check for outliers.
sns.distplot(df['price'])
# Out:
# /Users/leo_mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
#No outliers spotted
df['price'].fillna(df['price'].mean(),inplace=True)
df.isna().sum()
# Out:
# host_identity_verified            289
# host name                         404
# neighbourhood group                29
# neighbourhood                      16
# lat                                 8
# long                                8
# instant_bookable                  105
# cancellation_policy                76
# room type                           0
# Construction year                 214
# price                               0
# service fee                         0
# minimum nights                    400
# number of reviews                   0
# reviews per month                   0
# review rate number                319
# calculated host listings count    319
# availability 365                    0
# review_year                         0
# dtype: int64

# %%
sns.distplot(df['availability 365'])
# Out:
# /Users/leo_mac/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='availability 365', ylabel='Density'>

# %%
df
# Out:
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# 1                    verified     Jenna           Manhattan
# 2                         NaN     Elise           Manhattan
# 3                 unconfirmed     Garry            Brooklyn
# 4                    verified    Lyndon           Manhattan
# ...                       ...       ...                 ...
# 102053            unconfirmed    Mariam            Brooklyn
# 102054               verified      Trey            Brooklyn
# 102055               verified   Michael            Brooklyn
# 102056            unconfirmed   Shireen           Manhattan
# 102057               verified   Stanley           Manhattan
#
#              neighbourhood       lat      long instant_bookable  \
# 0               Kensington  40.64749 -73.97237            False
# 1                  Midtown  40.75362 -73.98377            False
# 2                   Harlem  40.80902 -73.94190             True
# 3              ClintonHill  40.68514 -73.95976             True
# 4               EastHarlem  40.79851 -73.94399            False
# ...                    ...       ...       ...              ...
# 102053            Flatbush  40.64945 -73.96108             True
# 102054            Bushwick  40.69872 -73.92718            False
# 102055  Bedford-Stuyvesant  40.67810 -73.90822             True
# 102056              Harlem  40.81248 -73.94317             True
# 102057              Harlem  40.81315 -73.94747            False
#
#        cancellation_policy       room type  Construction year   price  \
# 0                   strict     Privateroom             2020.0   966.0
# 1                 moderate  Entirehome/apt             2007.0   142.0
# 2                 flexible     Privateroom             2005.0   620.0
# 3                 moderate  Entirehome/apt             2005.0   368.0
# 4                 moderate  Entirehome/apt             2009.0   204.0
# ...                    ...             ...                ...     ...
# 102053            moderate     Privateroom                NaN   696.0
# 102054            flexible     Privateroom                NaN   909.0
# 102055            moderate  Entirehome/apt                NaN   387.0
# 102056              strict     Privateroom                NaN   848.0
# 102057            flexible  Entirehome/apt             2011.0  1128.0
#
#         service fee  minimum nights  number of reviews  reviews per month  \
# 0        193.000000            10.0                9.0           0.210000
# 1         28.000000            30.0               45.0           0.380000
# 2        124.000000             3.0                0.0           1.375408
# 3         74.000000            30.0              270.0           4.640000
# 4         41.000000            10.0                9.0           0.100000
# ...             ...             ...                ...                ...
# 102053   125.039249             7.0               12.0           0.440000
# 102054   125.039249             1.0               19.0           0.720000
# 102055   125.039249             2.0               50.0           3.120000
# 102056   125.039249             2.0                0.0           1.375408
# 102057   125.039249             4.0               22.0           0.850000
#
#         review rate number  calculated host listings count  availability 365  \
# 0                      4.0                             6.0             286.0
# 1                      4.0                             2.0             228.0
# 2                      5.0                             1.0             352.0
# 3                      4.0                             1.0             322.0
# 4                      3.0                             1.0             289.0
# ...                    ...                             ...               ...
# 102053                 5.0                             1.0               0.0
# 102054                 3.0                             2.0               0.0
# 102055                 4.0                             2.0             235.0
# 102056                 1.0                             1.0               0.0
# 102057                 4.0                             1.0             238.0
#
#                 review_year
# 0       2021-10-19 00:00:00
# 1       2022-05-21 00:00:00
# 2                         0
# 3       2019-07-05 00:00:00
# 4       2018-11-19 00:00:00
# ...                     ...
# 102053  2019-03-27 00:00:00
# 102054  2017-08-31 00:00:00
# 102055  2019-06-26 00:00:00
# 102056                    0
# 102057  2019-06-15 00:00:00
#
# [102058 rows x 19 columns]

# %%
#There are some negative values in availability 365 columns which is not possible.
#It can be count as a outliers

# %%
df.drop(df[df['availability 365']<0].index,inplace=True)

#outliers removed
df.isna().sum()
# Out:
# host_identity_verified            287
# host name                         404
# neighbourhood group                29
# neighbourhood                      16
# lat                                 8
# long                                8
# instant_bookable                  104
# cancellation_policy                75
# room type                           0
# Construction year                 210
# price                               0
# service fee                         0
# minimum nights                    394
# number of reviews                   0
# reviews per month                   0
# review rate number                318
# calculated host listings count    316
# availability 365                    0
# review_year                         0
# dtype: int64

# %%
df["host_identity_verified"].value_counts()
# Out:
# unconfirmed    50721
# verified       50619
# Name: host_identity_verified, dtype: int64

# %%
df["host_identity_verified"].fillna( method ='ffill', inplace = True)

# %%
df.drop(['instant_bookable'],axis=1,inplace=True)

# %%
df["cancellation_policy"].fillna( method ='ffill', inplace = True)

# %%
df.isna().sum()
# Out:
# host_identity_verified              0
# host name                         404
# neighbourhood group                29
# neighbourhood                      16
# lat                                 8
# long                                8
# cancellation_policy                 0
# room type                           0
# Construction year                 210
# price                               0
# service fee                         0
# minimum nights                    394
# number of reviews                   0
# reviews per month                   0
# review rate number                318
# calculated host listings count    316
# availability 365                    0
# review_year                         0
# dtype: int64

# %% [markdown]
# From the values here i found that some of the columns contain outliers. from max values and mean values comparison i can see that there is a huge difference between both values. Mean is very much sensitive to outliers
# For example Column minimum nights max values 5645 but mean is 8.13. Like this there are three columns availability 365, minimum nights.

# %%
df[df['availability 365']>500]
# Out:
#       host_identity_verified host name neighbourhood group neighbourhood  \
# 70866               verified     Laura           Manhattan        Harlem
#
#             lat      long cancellation_policy       room type  \
# 70866  40.81623 -73.94907              strict  Entirehome/apt
#
#        Construction year   price  service fee  minimum nights  \
# 70866             2009.0  1186.0        237.0             3.0
#
#        number of reviews  reviews per month  review rate number  \
# 70866              232.0               3.22                 5.0
#
#        calculated host listings count  availability 365          review_year
# 70866                             1.0            3677.0  2019-06-13 00:00:00

# %%
df.drop(df[df['availability 365']>500].index,inplace=True)

##outlier removed for availability 365 column.

# %%
df.describe()
# Out:
#                  lat           long  Construction year          price  \
# count  101618.000000  101618.000000      101416.000000  101626.000000
# mean       40.728085     -73.949608        2012.489785     625.449584
# std         0.055869       0.049540           5.765092     331.262176
# min        40.499790     -74.249840        2003.000000      50.000000
# 25%        40.688720     -73.982560        2007.000000     341.000000
# 50%        40.722270     -73.954430        2012.000000     625.355580
# 75%        40.762760     -73.932320        2017.000000     912.000000
# max        40.916970     -73.705220        2022.000000    1200.000000
#
#          service fee  minimum nights  number of reviews  reviews per month  \
# count  101626.000000   101232.000000      101626.000000      101626.000000
# mean      125.058338        8.130621          27.416419           1.376672
# std        66.235471       30.651076          49.453765           1.607917
# min        10.000000    -1223.000000           0.000000           0.010000
# 25%        68.000000        2.000000           1.000000           0.280000
# 50%       125.000000        3.000000           7.000000           1.050000
# 75%       182.000000        5.000000          30.000000           1.710000
# max       240.000000     5645.000000        1024.000000          90.000000
#
#        review rate number  calculated host listings count  availability 365
# count       101308.000000                   101310.000000     101626.000000
# mean             3.279968                        7.949304        141.008679
# std              1.284230                       32.315801        134.951084
# min              1.000000                        1.000000          0.000000
# 25%              2.000000                        1.000000          3.000000
# 50%              3.000000                        1.000000         96.000000
# 75%              4.000000                        2.000000        268.000000
# max              5.000000                      332.000000        426.000000

# %%
df[df['minimum nights']>1000]
# Out:
#       host_identity_verified  host name neighbourhood group     neighbourhood  \
# 350                 verified    Russell            Brooklyn      CrownHeights
# 5768                verified  Genevieve           Manhattan  GreenwichVillage
# 42398               verified      Elena            Brooklyn          Bushwick
# 42407            unconfirmed         Gk            Brooklyn          BayRidge
#
#             lat      long cancellation_policy       room type  \
# 350    40.67473 -73.94494            flexible  Entirehome/apt
# 5768   40.73293 -73.99782            moderate  Entirehome/apt
# 42398  40.70235 -73.92892            flexible     Privateroom
# 42407  40.63189 -74.02322            moderate  Entirehome/apt
#
#        Construction year   price  service fee  minimum nights  \
# 350               2003.0  1142.0        228.0          3455.0
# 5768              2008.0   379.0         76.0          1250.0
# 42398             2013.0   453.0         91.0          5645.0
# 42407             2022.0   843.0        169.0          2645.0
#
#        number of reviews  reviews per month  review rate number  \
# 350                  0.0           1.375408                 1.0
# 5768                 2.0           0.030000                 2.0
# 42398                1.0           0.880000                 4.0
# 42407               14.0           3.590000                 3.0
#
#        calculated host listings count  availability 365          review_year
# 350                               1.0               0.0                    0
# 5768                              1.0              26.0  2014-11-09 00:00:00
# 42398                             1.0               0.0  2019-06-05 00:00:00
# 42407                             1.0             271.0  2019-06-14 00:00:00

# %%
df.drop(df[df['minimum nights']>1000].index,inplace=True)

# %%
df.isna().sum()
# Out:
# host_identity_verified              0
# host name                         404
# neighbourhood group                29
# neighbourhood                      16
# lat                                 8
# long                                8
# cancellation_policy                 0
# room type                           0
# Construction year                 210
# price                               0
# service fee                         0
# minimum nights                    394
# number of reviews                   0
# reviews per month                   0
# review rate number                318
# calculated host listings count    316
# availability 365                    0
# review_year                         0
# dtype: int64

# %%
df['host name'].fillna("other",inplace=True)

# %%
df[df['neighbourhood group'].isna()]

##percentage of null rows in the column
df['neighbourhood group'].isna().sum()*100/len(df)
# Out:
# 0.028537127787290152

# %% [markdown]
# only 0.02% of data of neighbourhood group contain null values so we can drop it as outliers

# %%
df.dropna(subset=['neighbourhood group'],inplace=True)

# %% [markdown]
# #percentage of null values in the neighbourhood column is very very low tha is why we can remove this rows also

# %%
df.dropna(subset=['neighbourhood'],inplace=True)

# %%
df['calculated host listings count'].fillna(df['calculated host listings count'].mean(),inplace=True)

# %%
df['Construction year'].fillna('Not_known',inplace=True)

# %%
df['minimum nights'].fillna(df['minimum nights'].mean(),inplace=True)

# %%
df
# Out:
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# 1                    verified     Jenna           Manhattan
# 2                    verified     Elise           Manhattan
# 3                 unconfirmed     Garry            Brooklyn
# 4                    verified    Lyndon           Manhattan
# ...                       ...       ...                 ...
# 102053            unconfirmed    Mariam            Brooklyn
# 102054               verified      Trey            Brooklyn
# 102055               verified   Michael            Brooklyn
# 102056            unconfirmed   Shireen           Manhattan
# 102057               verified   Stanley           Manhattan
#
#              neighbourhood       lat      long cancellation_policy  \
# 0               Kensington  40.64749 -73.97237              strict
# 1                  Midtown  40.75362 -73.98377            moderate
# 2                   Harlem  40.80902 -73.94190            flexible
# 3              ClintonHill  40.68514 -73.95976            moderate
# 4               EastHarlem  40.79851 -73.94399            moderate
# ...                    ...       ...       ...                 ...
# 102053            Flatbush  40.64945 -73.96108            moderate
# 102054            Bushwick  40.69872 -73.92718            flexible
# 102055  Bedford-Stuyvesant  40.67810 -73.90822            moderate
# 102056              Harlem  40.81248 -73.94317              strict
# 102057              Harlem  40.81315 -73.94747            flexible
#
#              room type Construction year   price  service fee  minimum nights  \
# 0          Privateroom            2020.0   966.0   193.000000            10.0
# 1       Entirehome/apt            2007.0   142.0    28.000000            30.0
# 2          Privateroom            2005.0   620.0   124.000000             3.0
# 3       Entirehome/apt            2005.0   368.0    74.000000            30.0
# 4       Entirehome/apt            2009.0   204.0    41.000000            10.0
# ...                ...               ...     ...          ...             ...
# 102053     Privateroom         Not_known   696.0   125.039249             7.0
# 102054     Privateroom         Not_known   909.0   125.039249             1.0
# 102055  Entirehome/apt         Not_known   387.0   125.039249             2.0
# 102056     Privateroom         Not_known   848.0   125.039249             2.0
# 102057  Entirehome/apt            2011.0  1128.0   125.039249             4.0
#
#         number of reviews  reviews per month  review rate number  \
# 0                     9.0           0.210000                 4.0
# 1                    45.0           0.380000                 4.0
# 2                     0.0           1.375408                 5.0
# 3                   270.0           4.640000                 4.0
# 4                     9.0           0.100000                 3.0
# ...                   ...                ...                 ...
# 102053               12.0           0.440000                 5.0
# 102054               19.0           0.720000                 3.0
# 102055               50.0           3.120000                 4.0
# 102056                0.0           1.375408                 1.0
# 102057               22.0           0.850000                 4.0
#
#         calculated host listings count  availability 365          review_year
# 0                                  6.0             286.0  2021-10-19 00:00:00
# 1                                  2.0             228.0  2022-05-21 00:00:00
# 2                                  1.0             352.0                    0
# 3                                  1.0             322.0  2019-07-05 00:00:00
# 4                                  1.0             289.0  2018-11-19 00:00:00
# ...                                ...               ...                  ...
# 102053                             1.0               0.0  2019-03-27 00:00:00
# 102054                             2.0               0.0  2017-08-31 00:00:00
# 102055                             2.0             235.0  2019-06-26 00:00:00
# 102056                             1.0               0.0                    0
# 102057                             1.0             238.0  2019-06-15 00:00:00
#
# [101577 rows x 18 columns]

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #review rate number is not strongly correlated with other columns so we can keep the column as it was before
